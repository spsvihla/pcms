# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import gamma

from utils.moment_asymptotics import *

# %% [markdown]
# ## Asymptotic Distribution of EPL

# %%
n_samples = 1000
n_leaves = 10000

draw_ = draw_epl(n_samples=n_samples, n_leaves=n_leaves)

# %%
q = np.ceil(np.log2(n_leaves))
# epl_min = (q + 1) * n_leaves - 2**q
epl_min = np.min(draw_)
epl_max = np.max(draw_)
mu_n = exp_epln_exact(n_leaves)
sigma2_n = var_epl_exact(n_leaves)
m_n = (mu_n - epl_min)

# %% [markdown]
# ### Part 1: Standard scaling

# %%
draw0 = (draw_ - mu_n) / sigma2_n

# %%
n_bins = 100
hist, bins = np.histogram(draw0, bins=n_bins, density=True)
centers = (bins[:-1] + bins[1:]) / 2

# %%
xvals = np.linspace(bins[0], bins[-1], 1000)

fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(draw0, bins=n_bins, density=True, alpha=0.6, color='#3498db', edgecolor='black')
ax.set_xlabel(r'$\mathrm{EPL}(\mathrm{T}_n)$', fontsize=14)
ax.set_ylabel(r'Density', fontsize=14)
ax.grid(visible=True, linestyle='--', alpha=0.6)
ax.legend(fontsize=12)
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_29048/761234866.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=12)

# %% [markdown]
# ### Part 2: Scaling to fixed first moment

# %%
draw1 = (draw_ - epl_min) / m_n

# %%
shape = m_n**2 / sigma2_n
scale = 1 / shape
print(f"Shape: {shape}, Scale: {scale}")
# Out:
# Shape: 4.36671587720285, Scale: 0.2290050527950908

# %%
n_bins = 100
hist, bins = np.histogram(draw1, bins=n_bins, density=True)
centers = (bins[:-1] + bins[1:]) / 2

# %%
xvals = np.linspace(bins[0], bins[-1], 1000)
gamma_pdf = gamma.pdf(xvals, shape, scale=scale)

fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(draw1, bins=n_bins, density=True, alpha=0.6, color='#3498db', edgecolor='black')
ax.plot(xvals, gamma_pdf, color='#e74c3c', lw=2, label=rf"Gamma($\alpha$={shape:.2f}, $\theta$={scale:.2f}) density")
ax.set_xlabel(r'$\mathrm{EPL}(\mathrm{T}_n)$', fontsize=14)
ax.set_ylabel(r'Density', fontsize=14)
ax.grid(visible=True, linestyle='--', alpha=0.6)
ax.legend(fontsize=12)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Part 3: Scaling to fixed ratio of first moment and variance

# %%
draw2 = (draw_ - epl_min) * m_n / sigma2_n

# %%
shape = m_n**2 / sigma2_n
scale = 1
print(f"Shape: {shape}, Scale: {scale}")
# Out:
# Shape: 4.36671587720285, Scale: 1

# %%
n_bins = 100
hist, bins = np.histogram(draw2, bins=n_bins, density=True)
centers = (bins[:-1] + bins[1:]) / 2

# %%
xvals = np.linspace(bins[0], bins[-1], 1000)
gamma_pdf = gamma.pdf(xvals, shape, scale=scale)

fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(draw2, bins=n_bins, density=True, alpha=0.6, color='#3498db', edgecolor='black')
ax.plot(xvals, gamma_pdf, color='#e74c3c', lw=2, label=rf"Gamma($\alpha$={shape:.2f}, $\theta$={scale:.2f}) density")
ax.set_xlabel(r'$\mathrm{EPL}(\mathrm{T}_n)$', fontsize=14)
ax.set_ylabel(r'Density', fontsize=14)
ax.grid(visible=True, linestyle='--', alpha=0.6)
ax.legend(fontsize=12)
plt.tight_layout()

plt.show()
